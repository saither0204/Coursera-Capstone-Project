# %%
print("This notebook will be used for Captone Project")
# Out:
# This notebook will be used for Captone Project

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\__init__.py in <module>
#       9 for dependency in hard_dependencies:
#      10     try:
# ---> 11         __import__(dependency)
#      12     except ImportError as e:
#      13         missing_dependencies.append(f"{dependency}: {e}")
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\numpy\__init__.py in <module>
#     303
#     304     if sys.platform == "win32" and sys.maxsize > 2**32:
# --> 305         _win_os_check()
#     306
#     307     del _win_os_check
#
# ...
